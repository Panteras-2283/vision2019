# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.rcParams['figure.figsize'] = (20,10)

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor

from feather import read_dataframe

# %%
df = pd.read_csv('./data/dataFinal.csv')
df.dtypes
# Out:
# Unnamed: 0      object
# yDistance      float64
# xDistance      float64
# theta          float64
# width          float64
# height         float64
# centerX        float64
# centerY        float64
# aspectRatio    float64
# heightRatio    float64
# yDiff          float64
# dtype: object

# %%
df = df.drop('Unnamed: 0', axis=1)
df['theta'].unique()
# Out:
# array([  0.,  -5.,   5.,  10.,  15.,  20.,  25., -10., -15., -20., -25.,
#        -30.,  30., -35.,  35.,  40., -40.])

# %%
df.loc[df.theta=='-10c', 'theta'] = '-10'

# %%
df.theta = df.theta.astype(float)
df.yDistance = df.yDistance.astype(float)
df.xDistance = df.xDistance.astype(float)

# %%
sns.pairplot(df)

# %%
df.columns = ['y', 'x', 'theta', 'width', 'height', 'center_x', 'center_y', 'aspect_ratio', 'height_ratio', 'y_diff']

# %%
df.columns
# Out:
# Index(['y', 'x', 'theta', 'width', 'height', 'center_x', 'center_y',
#        'aspect_ratio', 'height_ratio', 'y_diff'],
#       dtype='object')

# %%
df2 = df.groupby(['y','x','theta']).agg({'width':'mean', 'height':'mean', 'center_x':'mean', 'center_y':'mean',
                                  'aspect_ratio':'mean', 'height_ratio':'mean', 'y_diff':'mean'}).reset_index()

# %%
# NN
X = df2.drop(['x', 'y', 'theta', 'width'], axis=1)
y = df2[['x', 'y', 'theta']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
nn = MLPRegressor((100,100,100), max_iter=1000)

# %%
nn.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1000, 1000, 1000, 700, 500, 200, 100),
#        learning_rate='constant', learning_rate_init=0.001, max_iter=1000,
#        momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#        power_t=0.5, random_state=None, shuffle=True, solver='adam',
#        tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
sns.scatterplot(y_train.x, nn.predict(X_train)[:,0])

# %%
sns.scatterplot(y_train.y, nn.predict(X_train)[:,1])

# %%
sns.scatterplot(y_train.theta, nn.predict(X_train)[:,2])
